# %%
import pandas as pd

# %%
df=pd.read_csv('developer_survey_2019\survey_results_public.csv')

# %%
df['Respondent']
df.set_index('EdLevel',inplace=True)
df.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-16ade1e28413> in <module>
#       1 df['Respondent']
# ----> 2 df.set_index('EdLevel',inplace=True)
#       3 df.reset_index(inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['EdLevel'] are in the columns"

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Untitled Folder'

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.head
# Out:
# <bound method NDFrame.head of        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
df.loc[0:3,["Respondent","OpenSourcer"]]
# Out:
#    Respondent              OpenSourcer
# 0           1                    Never
# 1           2  Less than once per year
# 2           3                    Never
# 3           4                    Never

# %%
df.iloc[[0,3],[0,3]]
# Out:
#    Respondent OpenSourcer
# 0           1       Never
# 3           4       Never

# %%
df.loc[0:4,"Respondent":"OpenSourcer"]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often

# %%
r=[1,2,3,5,6]
c=[0,2,6,8,9]
df.iloc[r,c]
# Out:
#    Respondent Hobbyist                 Country  \
# 1           2       No  Bosnia and Herzegovina
# 2           3      Yes                Thailand
# 3           4       No           United States
# 5           6      Yes                  Canada
# 6           7       No                 Ukraine
#
#                                              EdLevel  \
# 1  Secondary school (e.g. American high school, G...
# 2           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor
# 1                                                NaN
# 2                      Web development or web design
# 3  Computer science, computer engineering, or sof...
# 5                          Mathematics or statistics
# 6  Another engineering discipline (ex. civil, ele...

# %%
df.loc[df.Hobbyist=="Yes","Country"]
# Out:
# 0        United Kingdom
# 2              Thailand
# 4               Ukraine
# 5                Canada
# 7                 India
#               ...
# 88872    Czech Republic
# 88875          Pakistan
# 88877     United States
# 88878            Canada
# 88882             Spain
# Name: Country, Length: 71257, dtype: object

# %%
df.loc[(df.Hobbyist=="Yes") & (df.Country=="Canada") ,"Hobbyist"]
# Out:
# 5        Yes
# 20       Yes
# 36       Yes
# 78       Yes
# 99       Yes
#         ...
# 88664    Yes
# 88751    Yes
# 88771    Yes
# 88801    Yes
# 88878    Yes
# Name: Hobbyist, Length: 2685, dtype: object

# %%
df.iloc[list((df.Hobbyist=="Yes") & (df.Country=="Canada")) ,5:10]
# Out:
#                                    Employment Country         Student  \
# 5                          Employed full-time  Canada              No
# 20                                        NaN  Canada             NaN
# 36                         Employed part-time  Canada  Yes, full-time
# 78                         Employed full-time  Canada  Yes, full-time
# 99                         Employed full-time  Canada              No
# ...                                       ...     ...             ...
# 88664                      Employed part-time  Canada  Yes, full-time
# 88751      Not employed, but looking for work  Canada              No
# 88771  Not employed, and not looking for work  Canada              No
# 88801                      Employed full-time  Canada              No
# 88878  Not employed, and not looking for work  Canada              No
#
#                                                  EdLevel  \
# 5               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...

# %%
df.sort_index(axis=1)
# Out:
#         Age Age1stCode BetterLife  \
# 0      14.0         10        Yes
# 1      19.0         17        Yes
# 2      28.0         22        Yes
# 3      22.0         16        Yes
# 4      30.0         14        Yes
# ...     ...        ...        ...
# 88878   NaN        NaN        Yes
# 88879   NaN        NaN        NaN
# 88880   NaN        NaN        NaN
# 88881   NaN        NaN        NaN
# 88882  18.0         11        Yes
#
#                                             BlockchainIs BlockchainOrg  \
# 0                                                    NaN           NaN
# 1      Useful across many domains and could change ma...           NaN
# 2                                                    NaN           NaN
# 3      Useful for decentralized currency (i.e., Bitcoin)    Not at all
# 4                                                    NaN    Not at all
# ...                                                  ...           ...
# ...

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#            YearsCodePro YearsCode  WorkWeekHrs  \
# 0                   NaN         4          NaN
# 1                   NaN       NaN          NaN
# 2                     1         3         40.0
# 3      Less than 1 year         3         80.0
# 4                     9        16         55.0
# ...                 ...       ...          ...
# 88878               NaN       NaN          NaN
# 88879               NaN       NaN          NaN
# 88880               NaN       NaN          NaN
# 88881               NaN       NaN          NaN
# 88882                 3         8          NaN
#
#                              WorkRemote  \
# 0                                   NaN
# 1                                   NaN
# 2      Less than once per month / Never
# 3      Less than once per month / Never
# 4                 A few days each month
# ...                                 ...
# 88878                               NaN
# 88879                               NaN
# ...

# %%
df.sample(15)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 80292       80794                     I am a developer by profession      Yes
# 32588       32787                     I am a developer by profession      Yes
# 66820       67250  I am not primarily a developer, but I write co...      Yes
# 51940       52275                     I am a developer by profession      Yes
# 41579       41843                     I am a developer by profession      Yes
# 67050       67482                     I am a developer by profession      Yes
# 31075       31261                     I am a developer by profession      Yes
# 53337       53676                     I am a developer by profession      Yes
# 39061       39302                     I am a developer by profession      Yes
# 13545       13608                     I am a developer by profession      Yes
# 25448       25597  I used to be a developer by profession, but no...      Yes
# ...

# %%
left={"rollno":[1,2,3,4,5],"name":["abc","xyz","lmn","pqr","def"],"Subject":["a","h","t","o","y"]}

# %%
left=pd.DataFrame(left)

# %%
left
# Out:
#    rollno name Subject
# 0       1  abc       a
# 1       2  xyz       h
# 2       3  lmn       t
# 3       4  pqr       o
# 4       5  def       y

# %%
right={"rollno":[1,2,3,6],"name":["abc","xyz","lmn","yui"],"Subject":["a","h","p","u"]}

# %%
right=pd.DataFrame(right)

# %%
right
# Out:
#    rollno name Subject
# 0       1  abc       a
# 1       2  xyz       h
# 2       3  lmn       p
# 3       6  yui       u

# %%
left,right
# Out:
# (   rollno name Subject
#  0       1  abc       a
#  1       2  xyz       h
#  2       3  lmn       t
#  3       4  pqr       o
#  4       5  def       y,
#     rollno name Subject
#  0       1  abc       a
#  1       2  xyz       h
#  2       3  lmn       p
#  3       6  yui       u)

# %%
print(left,right)
# Out:
#    rollno name Subject
# 0       1  abc       a
# 1       2  xyz       h
# 2       3  lmn       t
# 3       4  pqr       o
# 4       5  def       y    rollno name Subject
# 0       1  abc       a
# 1       2  xyz       h
# 2       3  lmn       p
# 3       6  yui       u

# %%
pd.merge(left,right,on="rollno")
# Out:
#    rollno name_x Subject_x name_y Subject_y
# 0       1    abc         a    abc         a
# 1       2    xyz         h    xyz         h
# 2       3    lmn         t    lmn         p

# %%
pd.merge(left,right,on=["rollno","Subject"])
# Out:
#    rollno name_x Subject name_y
# 0       1    abc       a    abc
# 1       2    xyz       h    xyz

# %%
pd.merge(left,right,on="rollno",how="left")
# Out:
#    rollno name_x Subject_x name_y Subject_y
# 0       1    abc         a    abc         a
# 1       2    xyz         h    xyz         h
# 2       3    lmn         t    lmn         p
# 3       4    pqr         o    NaN       NaN
# 4       5    def         y    NaN       NaN

# %%
pd.merge(left,right,on="Subject",how="right")
# Out:
#    rollno_x name_x Subject  rollno_y name_y
# 0       1.0    abc       a         1    abc
# 1       2.0    xyz       h         2    xyz
# 2       NaN    NaN       p         3    lmn
# 3       NaN    NaN       u         6    yui

# %%
pd.merge(left,right,on="Subject",how="outer")
# Out:
#    rollno_x name_x Subject  rollno_y name_y
# 0       1.0    abc       a       1.0    abc
# 1       2.0    xyz       h       2.0    xyz
# 2       3.0    lmn       t       NaN    NaN
# 3       4.0    pqr       o       NaN    NaN
# 4       5.0    def       y       NaN    NaN
# 5       NaN    NaN       p       3.0    lmn
# 6       NaN    NaN       u       6.0    yui

# %%
result=pd.concat([left,right])

# %%
frame=[left,right]

# %%
pd.concat(frame)
# Out:
#    rollno name Subject
# 0       1  abc       a
# 1       2  xyz       h
# 2       3  lmn       t
# 3       4  pqr       o
# 4       5  def       y
# 0       1  abc       a
# 1       2  xyz       h
# 2       3  lmn       p
# 3       6  yui       u

# %%
result
# Out:
#    rollno name Subject
# 0       1  abc       a
# 1       2  xyz       h
# 2       3  lmn       t
# 3       4  pqr       o
# 4       5  def       y
# 0       1  abc       a
# 1       2  xyz       h
# 2       3  lmn       p
# 3       6  yui       u
